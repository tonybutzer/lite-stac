# %% [markdown]
# # Hanoi via landsat-pds data lake
#
# ## no indexing necssary
#
#
# 1. test indexing software parse_MTL
# 2. test the cube - look ate panda_df
# 3. display the xarray

# %%
#!scp sleepy:./hanoi\* ../aoi/

# %%
import datetime
from litestacLib.ls_api import Litestac

# %%
my_aoi_file = '../aoi/hanoi.geojson'

date_range = (datetime.datetime(2013,2,1), datetime.datetime(2015,7,31))
# date_range = (datetime(2013,7,6), datetime(2018,7,7))

# es_index = 'rwanda'
# es_type = 'cube'

lc = Litestac()

measurements = ('red','green','blue',)

# return a pandas data frame product id creation date and red
panda_df = lc.search(my_aoi_file,
             time = date_range, measurements = measurements )
# Out:
# creating Litestac class
# return_stac_hits
# {'type': 'Polygon', 'coordinates': [[[105.743408203125, 20.92039691397189], [105.97686767578125, 20.92039691397189], [105.97686767578125, 21.1395879292953], [105.743408203125, 21.1395879292953], [105.743408203125, 20.92039691397189]]]}
# intersects search: 129 items
# 129 items
# 1 collections
# [landsat-8-l1]
# LC08_L1TP_127046_20150717_20170407_01_T1_B4.TIF
# LC08_L1TP_127045_20150717_20170407_01_T1_B4.TIF
# LC08_L1TP_126046_20150710_20170407_01_T1_B4.TIF
# LC08_L1TP_126045_20150710_20170407_01_T1_B4.TIF
# LC08_L1TP_127046_20150701_20170407_01_T1_B4.TIF
# LC08_L1TP_127045_20150701_20170407_01_T1_B4.TIF
# LC08_L1TP_127046_20150615_20170407_01_T1_B4.TIF
# LC08_L1TP_127045_20150615_20170407_01_T1_B4.TIF
# LC08_L1TP_126046_20150608_20170408_01_T1_B4.TIF
# LC08_L1TP_126045_20150608_20170408_01_T1_B4.TIF
# LC08_L1TP_127046_20150530_20170408_01_T1_B4.TIF
# LC08_L1TP_127045_20150530_20170408_01_T1_B4.TIF
# LC08_L1TP_126046_20150523_20170408_01_T1_B4.TIF
# LC08_L1TP_126045_20150523_20170408_01_T1_B4.TIF
# LC08_L1TP_127046_20150514_20170409_01_T1_B4.TIF
# LC08_L1TP_127045_20150514_20170409_01_T1_B4.TIF
# LC08_L1TP_126045_20150507_20180523_01_T1_B4.TIF
# LC08_L1TP_127046_20150428_20170409_01_T1_B4.TIF
# LC08_L1TP_126046_20150421_20180523_01_T1_B4.TIF
# LC08_L1TP_126045_20150421_20180523_01_T1_B4.TIF
# LC08_L1TP_127046_20150412_20170410_01_T1_B4.TIF
# LC08_L1TP_127045_20150412_20170410_01_T1_B4.TIF
# LC08_L1TP_126045_20150320_20170411_01_T1_B4.TIF
# LC08_L1TP_127046_20150223_20170412_01_T1_B4.TIF
# LC08_L1TP_127045_20150223_20170412_01_T1_B4.TIF
# LC08_L1TP_126046_20150216_20170412_01_T1_B4.TIF
# LC08_L1TP_126045_20150216_20170412_01_T1_B4.TIF
# LC08_L1TP_127046_20150122_20170413_01_T1_B4.TIF
# LC08_L1TP_127045_20150122_20170413_01_T1_B4.TIF
# LC08_L1TP_126046_20150115_20170414_01_T1_B4.TIF
# 106  LC08_L1TP  B4.TIF  127  045  2013-08-12
# 107  LC08_L1TP  B4.TIF  126  046  2013-08-05
# 108  LC08_L1TP  B4.TIF  126  045  2013-08-05
# 109  LC08_L1TP  B4.TIF  126  046  2013-07-20
# 110  LC08_L1TP  B4.TIF  126  045  2013-07-20
# 111  LC08_L1TP  B4.TIF  127  046  2013-07-11
# 112  LC08_L1TP  B4.TIF  126  046  2013-07-04
# 113  LC08_L1TP  B4.TIF  126  045  2013-07-04
# 114  LC08_L1TP  B4.TIF  126  046  2013-06-18
# 115  LC08_L1TP  B4.TIF  126  045  2013-06-18
# 116  LC08_L1TP  B4.TIF  127  046  2013-06-09
# 117  LC08_L1TP  B4.TIF  127  045  2013-06-09
# 118  LC08_L1TP  B4.TIF  126  046  2013-06-02
# 119  LC08_L1TP  B4.TIF  126  045  2013-06-02
# 120  LC08_L1TP  B4.TIF  127  046  2013-05-24
# 121  LC08_L1TP  B4.TIF  127  045  2013-05-24
# 122  LC08_L1TP  B4.TIF  126  046  2013-05-17
# 123  LC08_L1TP  B4.TIF  126  045  2013-05-17
# 124  LC08_L1TP  B4.TIF  127  046  2013-04-22
# 125  LC08_L1TP  B4.TIF  126  046  2013-04-15
# 126  LC08_L1TP  B4.TIF  126  045  2013-04-15
# 127  LC08_L1TP  B4.TIF  127  046  2013-04-03
# 128  LC08_L1TP  B4.TIF  127  045  2013-04-03
#
#                                                    red  \
# 0    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 1    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 2    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 3    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 4    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 5    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 6    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 7    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 8    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 9    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 10   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 11   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 12   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 13   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 14   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 15   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 16   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 17   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 18   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 19   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 20   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 21   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 22   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 23   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 24   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 25   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 26   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 27   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 28   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 29   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# ..                                                 ...
# 99   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 100  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 101  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 102  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 103  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 104  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 105  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 106  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 107  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 108  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 109  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 110  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 111  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 112  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 113  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 114  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 115  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 116  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 117  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 118  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 119  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 120  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 121  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 122  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 123  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 124  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 125  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 126  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 127  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 128  https://s3-us-west-2.amazonaws.com/landsat-pds...
#
#                                                  green  \
# 0    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 1    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 2    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 3    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 4    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 5    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 6    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 7    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 8    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 9    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 10   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 11   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 12   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 13   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 14   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 15   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 16   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 17   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 18   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 19   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 20   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 21   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 22   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 23   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 24   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 25   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 26   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 27   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 28   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 29   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# ..                                                 ...
# 99   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 100  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 101  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 102  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 103  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 104  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 105  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 106  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 107  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 108  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 109  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 110  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 111  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 112  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 113  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 114  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 115  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 116  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 117  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 118  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 119  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 120  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 121  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 122  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 123  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 124  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 125  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 126  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 127  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 128  https://s3-us-west-2.amazonaws.com/landsat-pds...
#
#                                                   blue  \
# 0    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 1    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 2    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 3    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 4    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 5    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 6    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 7    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 8    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 9    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 10   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 11   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 12   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 13   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 14   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 15   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 16   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 17   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 18   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 19   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 20   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 21   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 22   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 23   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 24   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 25   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 26   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 27   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 28   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 29   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# ..                                                 ...
# 99   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 100  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 101  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 102  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 103  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 104  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 105  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 106  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 107  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 108  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 109  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 110  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 111  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 112  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 113  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 114  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 115  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 116  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 117  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 118  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 119  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 120  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 121  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 122  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 123  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 124  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 125  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 126  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 127  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 128  https://s3-us-west-2.amazonaws.com/landsat-pds...
#
#                                                    nir  \
# 0    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 1    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 2    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 3    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 4    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 5    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 6    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 7    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 8    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 9    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 10   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 11   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 12   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 13   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 14   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 15   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 16   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 17   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 18   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 19   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 20   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 21   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 22   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 23   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 24   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 25   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 26   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 27   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 28   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 29   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# ..                                                 ...
# 99   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 100  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 101  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 102  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 103  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 104  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 105  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 106  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 107  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 108  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 109  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 110  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 111  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 112  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 113  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 114  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 115  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 116  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 117  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 118  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 119  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 120  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 121  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 122  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 123  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 124  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 125  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 126  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 127  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 128  https://s3-us-west-2.amazonaws.com/landsat-pds...
#
#                                               pixel_qa
# 0    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 1    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 2    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 3    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 4    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 5    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 6    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 7    https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 8    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 9    https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 10   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 11   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 12   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 13   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 14   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 15   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 16   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 17   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 18   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 19   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 20   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 21   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 22   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 23   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 24   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 25   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 26   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 27   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 28   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 29   https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# ..                                                 ...
# 99   https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 100  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 101  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 102  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 103  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 104  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 105  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 106  https://landsat-pds.s3.amazonaws.com/c1/L8/127...
# 107  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 108  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 109  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 110  https://landsat-pds.s3.amazonaws.com/c1/L8/126...
# 111  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 112  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 113  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 114  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 115  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 116  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 117  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 118  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 119  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 120  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 121  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 122  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 123  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 124  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 125  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 126  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 127  https://s3-us-west-2.amazonaws.com/landsat-pds...
# 128  https://s3-us-west-2.amazonaws.com/landsat-pds...
#
# [129 rows x 10 columns]

# %%
from lilcubeLib.lc_display import Ldisplay
ld = Ldisplay()
ld.map_geojson(my_aoi_file)
# Out:
# creating Ldisplay class
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
prune_panda_df = panda_df.loc[panda_df['path']=='127']

# %%
ds = lc.load(my_aoi_file, measurements, prune_panda_df)
# Out:
# thanks for constructing an  Xpart
# redfile is https://landsat-pds.s3.amazonaws.com/c1/L8/127/046/LC08_L1TP_127046_20150717_20170407_01_T1/LC08_L1TP_127046_20150717_20170407_01_T1_B4.TIF
# geojson_file is ../aoi/hanoi.geojson
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 7611, 'height': 7761, 'count': 1, 'crs': CRS.from_dict(init='epsg:32648'), 'transform': Affine(30.0, 0.0, 403185.0,
#        0.0, -30.0, 2352915.0), 'blockxsize': 512, 'blockysize': 512, 'tiled': True, 'compress': 'deflate', 'interleave': 'band'}
# CRS EPSG:32648
# [[[105.743408203125, 20.92039691397189], [105.97686767578125, 20.92039691397189], [105.97686767578125, 21.1395879292953], [105.743408203125, 21.1395879292953], [105.743408203125, 20.92039691397189]]]
# 813 804
# XS len 813
# YS len 804
# 403200.0 2352900.0
# 403230.0 2352870.0
# 403260.0 2352840.0
# 403290.0 2352810.0
# 403320.0 2352780.0
# 403350.0 2352750.0
# 403380.0 2352720.0
# 403410.0 2352690.0
# 403440.0 2352660.0
# 813
# 804
# (504, 1308)
# (5800, 6613)
# TONY len of time_coords 71
# total_shape = (71, 804, 813)
# INDEX= 0 red
# INDEX= 1 red
# INDEX= 2 red
# INDEX= 3 red
# INDEX= 4 red
# INDEX= 5 red
# INDEX= 6 red
# INDEX= 7 red
# INDEX= 8 red
# INDEX= 9 red
# INDEX= 10 red
# INDEX= 11 red
# INDEX= 12 red
# INDEX= 13 red
# INDEX= 14 red
# INDEX= 15 red
# INDEX= 16 red
# INDEX= 17 red
# INDEX= 18 red
# INDEX= 19 red
# INDEX= 20 red
# INDEX= 21 red
# INDEX= 22 red
# INDEX= 23 red
# INDEX= 24 red
# INDEX= 25 red
# INDEX= 26 red
# INDEX= 27 red
# INDEX= 28 red
# INDEX= 29 red
# INDEX= 30 red
# INDEX= 31 red
# INDEX= 32 red
# INDEX= 33 red
# INDEX= 34 red
# INDEX= 35 red
# INDEX= 36 red
# INDEX= 37 red
# INDEX= 38 red
# INDEX= 39 red
# INDEX= 40 red
# INDEX= 41 red
# INDEX= 42 red
# INDEX= 43 red
# INDEX= 44 red
# INDEX= 45 red
# INDEX= 46 red
# INDEX= 47 red
# INDEX= 48 red
# INDEX= 49 red
# INDEX= 50 red
# INDEX= 51 red
# INDEX= 52 red
# INDEX= 53 red
# INDEX= 54 red
# INDEX= 55 red
# INDEX= 56 red
# INDEX= 57 red
# INDEX= 58 red
# INDEX= 59 red
# INDEX= 60 red
# INDEX= 61 red
# INDEX= 62 red
# INDEX= 63 red
# INDEX= 64 red
# INDEX= 65 red
# INDEX= 66 red
# INDEX= 67 red
# INDEX= 68 red
# INDEX= 69 red
# INDEX= 70 red
# total_shape = (71, 804, 813)
# INDEX= 0 green
# INDEX= 1 green
# INDEX= 2 green
# INDEX= 3 green
# INDEX= 4 green
# INDEX= 5 green
# INDEX= 6 green
# INDEX= 7 green
# INDEX= 8 green
# INDEX= 9 green
# INDEX= 10 green
# INDEX= 11 green
# INDEX= 12 green
# INDEX= 13 green
# INDEX= 14 green
# INDEX= 15 green
# INDEX= 16 green
# INDEX= 17 green
# INDEX= 18 green
# INDEX= 19 green
# INDEX= 20 green
# INDEX= 21 green
# INDEX= 22 green
# INDEX= 23 green
# INDEX= 24 green
# INDEX= 25 green
# INDEX= 26 green
# INDEX= 27 green
# INDEX= 28 green
# INDEX= 29 green
# INDEX= 30 green
# INDEX= 31 green
# INDEX= 32 green
# INDEX= 33 green
# INDEX= 34 green
# INDEX= 35 green
# INDEX= 36 green
# INDEX= 37 green
# INDEX= 38 green
# INDEX= 39 green
# INDEX= 40 green
# INDEX= 41 green
# INDEX= 42 green
# INDEX= 43 green
# INDEX= 44 green
# INDEX= 45 green
# INDEX= 46 green
# INDEX= 47 green
# INDEX= 48 green
# INDEX= 49 green
# INDEX= 50 green
# INDEX= 51 green
# INDEX= 52 green
# INDEX= 53 green
# INDEX= 54 green
# INDEX= 55 green
# INDEX= 56 green
# INDEX= 57 green
# INDEX= 58 green
# INDEX= 59 green
# INDEX= 60 green
# INDEX= 61 green
# INDEX= 62 green
# INDEX= 63 green
# INDEX= 64 green
# INDEX= 65 green
# INDEX= 66 green
# INDEX= 67 green
# INDEX= 68 green
# INDEX= 69 green
# INDEX= 70 green
# total_shape = (71, 804, 813)
# INDEX= 0 blue
# INDEX= 1 blue
# INDEX= 2 blue
# INDEX= 3 blue
# INDEX= 4 blue
# INDEX= 5 blue
# INDEX= 6 blue
# INDEX= 7 blue
# INDEX= 8 blue
# INDEX= 9 blue
# INDEX= 10 blue
# INDEX= 11 blue
# INDEX= 12 blue
# INDEX= 13 blue
# INDEX= 14 blue
# INDEX= 15 blue
# INDEX= 16 blue
# INDEX= 17 blue
# INDEX= 18 blue
# INDEX= 19 blue
# INDEX= 20 blue
# INDEX= 21 blue
# INDEX= 22 blue
# INDEX= 23 blue
# INDEX= 24 blue
# INDEX= 25 blue
# INDEX= 26 blue
# INDEX= 27 blue
# INDEX= 28 blue
# INDEX= 29 blue
# INDEX= 30 blue
# INDEX= 31 blue
# INDEX= 32 blue
# INDEX= 33 blue
# INDEX= 34 blue
# INDEX= 35 blue
# INDEX= 36 blue
# INDEX= 37 blue
# INDEX= 38 blue
# INDEX= 39 blue
# INDEX= 40 blue
# INDEX= 41 blue
# INDEX= 42 blue
# INDEX= 43 blue
# INDEX= 44 blue
# INDEX= 45 blue
# INDEX= 46 blue
# INDEX= 47 blue
# INDEX= 48 blue
# INDEX= 49 blue
# INDEX= 50 blue
# INDEX= 51 blue
# INDEX= 52 blue
# INDEX= 53 blue
# INDEX= 54 blue
# INDEX= 55 blue
# INDEX= 56 blue
# INDEX= 57 blue
# INDEX= 58 blue
# INDEX= 59 blue
# INDEX= 60 blue
# INDEX= 61 blue
# INDEX= 62 blue
# INDEX= 63 blue
# INDEX= 64 blue
# INDEX= 65 blue
# INDEX= 66 blue
# INDEX= 67 blue
# INDEX= 68 blue
# INDEX= 69 blue
# INDEX= 70 blue

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (datePR: 71, time: 71, x: 813, y: 804)
# Coordinates:
#   * datePR   (datePR) <U18 '2015-07-17_127_046' ... '2013-04-03_127_045'
#   * time     (time) <U10 '2015-07-17' '2015-07-17' ... '2013-04-03' '2013-04-03'
#   * y        (y) float64 2.353e+06 2.353e+06 2.353e+06 ... 2.329e+06 2.329e+06
#   * x        (x) float64 4.032e+05 4.032e+05 4.033e+05 ... 4.275e+05 4.276e+05
# Data variables:
#     red      (datePR, y, x) int16 0 0 0 0 0 ... -22228 -21835 -21805 -21341
#     green    (datePR, y, x) int16 0 0 0 0 0 ... -23812 -23333 -23192 -22697
#     blue     (datePR, y, x) int16 0 0 0 0 0 ... -22301 -22336 -22161 -22128
# Attributes:
#     crs:      EPSG:32648

# %%
# %matplotlib inline
display_color = 'red'
ds[display_color].plot.imshow('x', 'y', col='datePR', col_wrap=4, cmap='prism')

# %%
from notebookLib.nb_DEAPlotting import nb_rgb

# nb_rgb(ds,bands = ['red', 'green', 'blue'], index = [0,1,6,7,8,11,13,14,15], index_dim='datePR',
       # percentile_stretch=(.2,.70), aspect=1.2)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-703eb92d23e3> in <module>
#       2
#       3 nb_rgb(ds,bands = ['red', 'green', 'blue'], index = [0,1,6,7,8,11,13,14,15], index_dim='datePR',
# ----> 4        percentile_stretch=(.2,.70), aspect=1.2)
#
# /opt/little-cloud/lib/notebookLib/notebookLib/nb_DEAPlotting.py in nb_rgb(ds, bands, index, index_dim, robust, percentile_stretch, col_wrap, size, aspect, savefig_path, savefig_kwargs, **kwargs)
#     193         if len(index) > 1:
#     194
# --> 195             img = da.plot.imshow(robust=robust, col=index_dim, col_wrap=col_wrap, size=size, **kwargs)
#     196
#     197         # If only one index is supplied, squeeze out index_dim and plot as a single panel
#
# ~/.local/lib/python3.6/site-packages/xarray/plot/plot.py in plotmethod(_PlotMethods_obj, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, colors, center, robust, extend, levels, infer_intervals, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#     915         for arg in ['_PlotMethods_obj', 'newplotfunc', 'kwargs']:
#     916             del allargs[arg]
# --> 917         return newplotfunc(**allargs)
#     918
#     919     # Add to class _PlotMethods
#
# ~/.local/lib/python3.6/site-packages/xarray/plot/plot.py in newplotfunc(darray, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, center, robust, extend, levels, infer_intervals, colors, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#     737             # See eg. https://github.com/matplotlib/matplotlib/pull/10220
#     738             if robust or vmax is not None or vmin is not None:
# --> 739                 darray = _rescale_imshow_rgb(darray, vmin, vmax, robust)
#     740                 vmin, vmax, robust = None, None, False
#     741
#
# ~/.local/lib/python3.6/site-packages/xarray/plot/plot.py in _rescale_imshow_rgb(darray, vmin, vmax, robust)
#     596     # After scaling, downcast to 32-bit float.  This substantially reduces
#     597     # memory usage after we hand `darray` off to matplotlib.
# --> 598     darray = ((darray.astype('f8') - vmin) / (vmax - vmin)).astype('f4')
#     599     with warnings.catch_warnings():
#     600         warnings.filterwarnings('ignore', 'xarray.ufuncs',
#
# ~/.local/lib/python3.6/site-packages/xarray/core/dataarray.py in func(self, other)
#    1970
#    1971             variable = (f(self.variable, other_variable)
# -> 1972                         if not reflexive
#    1973                         else f(other_variable, self.variable))
#    1974             coords = self.coords._merge_raw(other_coords)
#
# ~/.local/lib/python3.6/site-packages/xarray/core/variable.py in func(self, other)
#    1672             with np.errstate(all='ignore'):
#    1673                 new_data = (f(self_data, other_data)
# -> 1674                             if not reflexive
#    1675                             else f(other_data, self_data))
#    1676             result = Variable(dims, new_data, attrs=attrs)
#
# MemoryError:

# %%
from notebookLib.nb_DEAPlotting import animated_timeseries
# animated_timeseries(ds,output_path='./hanoi.mp4',bands = ['red', 'green', 'blue'], time_dim='datePR',  
      # percentile_stretch=(.2,.85), interval=1200)
# Out:
# Generating 71 frame animation
#     Exporting animation to ./hanoi.mp4

# %%
# !ls
# Out:
#  a1-rwanda-landsat-pds-datacube-classic-hardest.ipynb
#  a2-rwanda-landsat-pds-lake-odc-lite-elastic.ipynb
# 'a3-rwanda-landsat-pds-lake-odc-lite-STAC-via sat-search.ipynb'
# 'b1-hanoi-vietnam-landsat-pds-lake-odc-lite-STAC-via sat-search-Copy1.ipynb'
#  hanoi.mp4

# %% [markdown]
# [hanoi movie click HERE](hanoi.mp4)

# %%
from notebookLib.nb_animate import nb_animated_timeseries

nb_animated_timeseries(ds,output_path='./hanoi2.mp4',bands = ['red', 'green', 'blue'], time_dim='datePR',  
      interval=1200)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-14-5de847ffa086> in <module>
#       2
#       3 nb_animated_timeseries(ds,output_path='./hanoi2.mp4',bands = ['red', 'green', 'blue'], time_dim='datePR',
# ----> 4       interval=1200)
#
# /opt/little-cloud/lib/notebookLib/notebookLib/nb_animate.py in nb_animated_timeseries(ds, output_path, width_pixels, interval, bands, percentile_stretch, image_proc_func, title, show_date, annotation_kwargs, onebandplot_cbar, onebandplot_kwargs, shapefile_path, shapefile_kwargs, time_dim, x_dim, y_dim)
#     156                                                       time_dim=time_dim, x_dim=x_dim, y_dim=y_dim,
#     157                                                       percentile_stretch=percentile_stretch,
# --> 158                                                       image_proc_func=image_proc_func)
#     159
#     160             # Get time, x and y dimensions of dataset and calculate width vs height of plot
#
# /opt/little-cloud/lib/notebookLib/notebookLib/nb_animate.py in _ds_to_arrraylist(ds, bands, time_dim, x_dim, y_dim, percentile_stretch, image_proc_func)
#    1526
#    1527     # Compute percents
# -> 1528     p_low, p_high = ds[bands].to_array().quantile(percentile_stretch).values
#    1529
#    1530     array_list = []
#
# ~/.local/lib/python3.6/site-packages/xarray/core/dataset.py in to_array(self, dim, name)
#    3063         data_vars = [self.variables[k] for k in self.data_vars]
#    3064         broadcast_vars = broadcast_variables(*data_vars)
# -> 3065         data = duck_array_ops.stack([b.data for b in broadcast_vars], axis=0)
#    3066
#    3067         coords = dict(self.coords)
#
# ~/.local/lib/python3.6/site-packages/xarray/core/duck_array_ops.py in stack(arrays, axis)
#     201 def stack(arrays, axis=0):
#     202     """stack() with better dtype promotion rules."""
# --> 203     return _stack(as_shared_dtype(arrays), axis=axis)
#     204
#     205
#
# ~/.local/lib/python3.6/site-packages/xarray/core/duck_array_ops.py in f(*args, **kwargs)
#      44             else:
#      45                 wrapped = getattr(eager_module, name)
# ---> 46             return wrapped(*args, ** kwargs)
#      47     else:
#      48         def f(data, *args, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/numpy/core/shape_base.py in stack(arrays, axis, out)
#     421     sl = (slice(None),) * axis + (_nx.newaxis,)
#     422     expanded_arrays = [arr[sl] for arr in arrays]
# --> 423     return _nx.concatenate(expanded_arrays, axis=axis, out=out)
#     424
#     425
#
# MemoryError:
